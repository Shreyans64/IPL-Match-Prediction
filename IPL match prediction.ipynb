# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("match_up_impact.csv.zip")

# %%
df
# Out:
#             Batter          Bowler  dismissed  match_played  runs_scored  \
# 0      YBK Jaiswal  Mohammed Shami          0             3           23
# 1      YBK Jaiswal      Yash Dayal          0             2           11
# 2      YBK Jaiswal     Rashid Khan          0             2           13
# 3      YBK Jaiswal        TA Boult          0             3           11
# 4      YBK Jaiswal        R Ashwin          0             1           11
# ...            ...             ...        ...           ...          ...
# 24208   DS Lehmann           B Lee          0             1            4
# 24209   DS Lehmann        JR Hopes          0             1            5
# 24210   DS Lehmann     MF Maharoof          0             1            1
# 24211    AA Noffke      AB Agarkar          0             1            2
# 24212    AA Noffke      SC Ganguly          0             1            7
#
#        ball_faced  average  strike_rate  batsman_impact
# 0              18     23.0      127.778        0.942362
# 1              12     11.0       91.667        0.641669
# 2               9     13.0      144.444        0.984025
# 3               9     11.0      122.222        0.832637
# 4              13     11.0       84.615        0.597594
# ...           ...      ...          ...             ...
# 24208           3      4.0      133.333        0.858331
# 24209           5      5.0      100.000        0.656250
# 24210           2      1.0       50.000        0.318750
# 24211           8      2.0       25.000        0.168750
# 24212           4      7.0      175.000        1.137500
#
# [24213 rows x 9 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
print(df.head())
# Out:
#         Batter          Bowler  dismissed  match_played  runs_scored  \
# 0  YBK Jaiswal  Mohammed Shami          0             3           23
# 1  YBK Jaiswal      Yash Dayal          0             2           11
# 2  YBK Jaiswal     Rashid Khan          0             2           13
# 3  YBK Jaiswal        TA Boult          0             3           11
# 4  YBK Jaiswal        R Ashwin          0             1           11
#
#    ball_faced  average  strike_rate  batsman_impact
# 0          18     23.0      127.778        0.942362
# 1          12     11.0       91.667        0.641669
# 2           9     13.0      144.444        0.984025
# 3           9     11.0      122.222        0.832637
# 4          13     11.0       84.615        0.597594

# %%
print(df.describe())
# Out:
#           dismissed  match_played   runs_scored    ball_faced       average  \
# count  24213.000000  24213.000000  24213.000000  24213.000000  24213.000000
# mean       0.005369      1.927147     11.604469      9.331929     11.572582
# std        0.099831      1.752668     15.010791     11.016807     14.925147
# min        0.000000      1.000000      0.000000      1.000000      0.000000
# 25%        0.000000      1.000000      2.000000      3.000000      2.000000
# 50%        0.000000      1.000000      7.000000      6.000000      7.000000
# 75%        0.000000      2.000000     15.000000     11.000000     15.000000
# max        4.000000     20.000000    176.000000    134.000000    176.000000
#
#         strike_rate  batsman_impact
# count  24213.000000    24213.000000
# mean     116.022483        0.797469
# std       76.280048        0.516536
# min        0.000000        0.000000
# 25%       66.667000        0.429169
# 50%      100.000000        0.704606
# 75%      152.000000        1.096875
# max      600.000000        3.862500

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24213 entries, 0 to 24212
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Batter          24213 non-null  object
#  1   Bowler          24213 non-null  object
#  2   dismissed       24213 non-null  int64
#  3   match_played    24213 non-null  int64
#  4   runs_scored     24213 non-null  int64
#  5   ball_faced      24213 non-null  int64
#  6   average         24213 non-null  float64
#  7   strike_rate     24213 non-null  float64
#  8   batsman_impact  24213 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.5+ MB
# None

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Batter            0
# Bowler            0
# dismissed         0
# match_played      0
# runs_scored       0
# ball_faced        0
# average           0
# strike_rate       0
# batsman_impact    0
# dtype: int64

# %%
Performing an EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of runs_scored using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['runs_scored'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Runs Scored')
plt.xlabel('Runs Scored')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot for batsman_impact
plt.figure(figsize=(8, 6))
sns.boxplot(df['batsman_impact'], color='lightgreen')
plt.title('Box Plot of Batsman Impact')
plt.xlabel('Batsman Impact')
plt.show()
# Out:
# C:\Users\SAKSHI PARATE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Pairplot for numerical columns
sns.pairplot(df[['match_played', 'runs_scored', 'ball_faced', 'average', 'strike_rate', 'batsman_impact']])
plt.show()

# %%
# Selecting only numeric columns for correlation analysis
numeric_data = df.select_dtypes(include=['int64', 'float64'])

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
Best performance of batters against bowlers

# %%
# Find Unique Batters
unique_batters = df['Batter'].unique()

# Iterate Through Unique Batters and Find Best Runs Scored
for batter in unique_batters:
    best_runs_record = df[df['Batter'] == batter].loc[df[df['Batter'] == batter]['runs_scored'].idxmax()]
    print("Best runs scored by", batter, "against", best_runs_record['Bowler'], "is", best_runs_record['runs_scored'])
# Out:
# Best runs scored by YBK Jaiswal against Sandeep Sharma is 53
# Best runs scored by JC Buttler against Sandeep Sharma is 87
# Best runs scored by SV Samson against S Kaul is 114
# Best runs scored by D Padikkal against RD Chahar is 49
# Best runs scored by SO Hetmyer against JO Holder is 47
# Best runs scored by R Ashwin against SN Thakur is 22
# Best runs scored by R Parag against HV Patel is 37
# Best runs scored by TA Boult against Mohsin Khan is 13
# Best runs scored by OC McCoy against R Sai Kishore is 7
# Best runs scored by WP Saha against UT Yadav is 105
# Best runs scored by Shubman Gill against R Ashwin is 72
# Best runs scored by MS Wade against TA Boult is 21
# Best runs scored by HH Pandya against R Ashwin is 57
# Best runs scored by DA Miller against RA Jadeja is 108
# Best runs scored by V Kohli against R Ashwin is 160
# Best runs scored by F du Plessis against Mohammed Shami is 90
# Best runs scored by RM Patidar against KH Pandya is 33
# Best runs scored by GJ Maxwell against R Ashwin is 99
# Best runs scored by MK Lomror against YS Chahal is 24
# Best runs scored by KD Karthik against JD Unadkat is 104
# Best runs scored by Shahbaz Ahmed against M Prasidh Krishna is 24
# Best runs scored by PWH de Silva against KR Sen is 8
# Best runs scored by HV Patel against DJ Bravo is 29
# Best runs scored by JR Hazlewood against Arshdeep Singh is 6
# Best runs scored by Q de Kock against DL Chahar is 106
# Best runs scored by KL Rahul against JJ Bumrah is 147
# Best runs scored by M Vohra against M Morkel is 43
# Best runs scored by DJ Hooda against SN Thakur is 53
# Best runs scored by MP Stoinis against CJ Jordan is 58
# Best runs scored by E Lewis against HV Patel is 38
# Best runs scored by KH Pandya against Imran Tahir is 59
# Best runs scored by PVD Chameera against K Rabada is 12
# Best runs scored by PK Garg against SM Curran is 20
# Best runs scored by Abhishek Sharma against Rashid Khan is 47
# Best runs scored by RA Tripathi against SP Narine is 71
# Best runs scored by AK Markram against CV Varun is 40
# Best runs scored by N Pooran against KK Ahmed is 49
# Best runs scored by Washington Sundar against K Rabada is 27
# Best runs scored by R Shepherd against NT Ellis is 19
# Best runs scored by J Suchith against AR Patel is 17
# Best runs scored by B Kumar against UT Yadav is 15
# Best runs scored by Umran Malik against TG Southee is 3
# Best runs scored by JM Bairstow against UT Yadav is 57
# Best runs scored by S Dhawan against Harbhajan Singh is 147
# Best runs scored by M Shahrukh Khan against HV Patel is 24
# Best runs scored by MA Agarwal against YS Chahal is 69
# Best runs scored by LS Livingstone against Shahbaz Ahmed is 36
# Best runs scored by JM Sharma against Kuldeep Yadav is 28
# Best runs scored by PN Mankad against Umran Malik is 4
# Best runs scored by PP Shaw against DL Chahar is 80
# Best runs scored by DA Warner against SP Narine is 176
# Best runs scored by MR Marsh against R Ashwin is 22
# Best runs scored by RR Pant against Rashid Khan is 92
# Best runs scored by SN Khan against RA Jadeja is 33
# Best runs scored by R Powell against Umran Malik is 22
# Best runs scored by AR Patel against RA Jadeja is 59
# Best runs scored by SN Thakur against JJ Bumrah is 17
# Best runs scored by Kuldeep Yadav against TG Southee is 10
# Best runs scored by Ishan Kishan against Rashid Khan is 74
# Best runs scored by RG Sharma against PP Chawla is 146
# Best runs scored by D Brevis against RD Chahar is 28
# Best runs scored by Tilak Varma against YS Chahal is 33
# Best runs scored by TH David against T Natarajan is 36
# Best runs scored by Ramandeep Singh against Fazalhaq Farooqi is 14
# Best runs scored by DR Sams against Washington Sundar is 13
# Best runs scored by RD Gaikwad against LH Ferguson is 56
# Best runs scored by DP Conway against Kuldeep Yadav is 37
# Best runs scored by MM Ali against Rashid Khan is 52
# Best runs scored by N Jagadeesan against R Sai Kishore is 23
# Best runs scored by AT Rayudu against A Mishra is 100
# Best runs scored by MS Dhoni against DW Steyn is 111
# Best runs scored by Simarjeet Singh against OC McCoy is 3
# Best runs scored by MJ Santner against SL Malinga is 14
# Best runs scored by R Tewatia against HV Patel is 40
# Best runs scored by Rashid Khan against DJ Bravo is 26
# Best runs scored by VR Iyer against FA Allen is 26
# Best runs scored by N Rana against R Ashwin is 99
# Best runs scored by A Tomar against JO Holder is 4
# Best runs scored by SS Iyer against YS Chahal is 87
# Best runs scored by SW Billings against PP Chawla is 30
# Best runs scored by AD Russell against Mohammed Shami is 88
# Best runs scored by RK Singh against MP Stoinis is 18
# Best runs scored by SP Narine against R Ashwin is 60
# Best runs scored by UT Yadav against TA Boult is 19
# Best runs scored by KS Williamson against A Mishra is 96
# Best runs scored by T Stubbs against B Kumar is 1
# Best runs scored by R Sanjay Yadav against B Kumar is 0
# Best runs scored by JJ Bumrah against DT Christian is 12
# Best runs scored by Lalit Yadav against YS Chahal is 18
# Best runs scored by PBB Rajapaksa against PWH de Silva is 23
# Best runs scored by Harpreet Brar against HV Patel is 27
# Best runs scored by R Dhawan against Avesh Khan is 15
# Best runs scored by RD Chahar against KK Ahmed is 15
# Best runs scored by K Rabada against JJ Bumrah is 16
# Best runs scored by Arshdeep Singh against KK Ahmed is 5
# Best runs scored by JDS Neesham against RA Jadeja is 15
# Best runs scored by A Badoni against HH Pandya is 18
# Best runs scored by JO Holder against HV Patel is 26
# Best runs scored by Mohsin Khan against OC McCoy is 7
# Best runs scored by Avesh Khan against Rashid Khan is 12
# Best runs scored by S Dube against SN Thakur is 45
# Best runs scored by AM Rahane against PP Chawla is 115
# Best runs scored by Shashank Singh against LH Ferguson is 18
# Best runs scored by M Jansen against LH Ferguson is 7
# Best runs scored by Mohammed Siraj against DJ Bravo is 22
# Best runs scored by RV Uthappa against R Ashwin is 123
# Best runs scored by DJ Bravo against SL Malinga is 46
# Best runs scored by M Theekshana against HV Patel is 7
# Best runs scored by Mukesh Choudhary against Ramandeep Singh is 4
# Best runs scored by HR Shokeen against RA Jadeja is 17
# Best runs scored by HE van der Dussen against A Nortje is 6
# Best runs scored by KS Bharat against AR Patel is 25
# Best runs scored by KS Sharma against Yash Dayal is 4
# Best runs scored by SP Jackson against CH Morris is 11
# Best runs scored by PJ Cummins against JJ Bumrah is 46
# Best runs scored by TG Southee against DJ Bravo is 30
# Best runs scored by KA Pollard against DJ Bravo is 136
# Best runs scored by M Ashwin against PVD Chameera is 6
# Best runs scored by K Kartikeya against PJ Cummins is 2
# Best runs scored by RP Meredith against AD Russell is 0
# Best runs scored by RV Patel against RA Jadeja is 13
# Best runs scored by A Nortje against KK Ahmed is 3
# Best runs scored by KK Ahmed against TA Boult is 1
# Best runs scored by Kartik Tyagi against MR Marsh is 7
# Best runs scored by Fazalhaq Farooqi against JR Hazlewood is 1
# Best runs scored by B Indrajith against M Prasidh Krishna is 9
# Best runs scored by AJ Finch against Sandeep Sharma is 46
# Best runs scored by AS Roy against Avesh Khan is 0
# Best runs scored by Shivam Mavi against DJ Bravo is 18
# Best runs scored by Harshit Rana against JO Holder is 2
# Best runs scored by SA Yadav against R Ashwin is 106
# Best runs scored by B Sai Sudharsan against Arshdeep Singh is 27
# Best runs scored by Mandeep Singh against PP Chawla is 60
# Best runs scored by SA Abbott against P Kumar is 12
# Best runs scored by S Gopal against SN Thakur is 14
# Best runs scored by RA Jadeja against PP Chawla is 70
# Best runs scored by D Pretorius against JJ Bumrah is 12
# Best runs scored by PJ Sangwan against IK Pathan is 4
# Best runs scored by LH Ferguson against SN Thakur is 14
# Best runs scored by AS Joseph against Mohammed Shami is 11
# Best runs scored by KK Nair against A Mishra is 61
# Best runs scored by DJ Mitchell against K Kartikeya is 12
# Best runs scored by A Manohar against YS Chahal is 21
# Best runs scored by M Prasidh Krishna against LH Ferguson is 2
# Best runs scored by SS Prabhudessai against RA Jadeja is 16
# Best runs scored by MK Pandey against Harbhajan Singh is 85
# Best runs scored by JD Unadkat against DJ Bravo is 21
# Best runs scored by Anuj Rawat against JD Unadkat is 21
# Best runs scored by Yash Dayal against AD Russell is 0
# Best runs scored by NT Ellis against B Kumar is 8
# Best runs scored by VG Arora against Mohammed Shami is 1
# Best runs scored by Ravi Bishnoi against Sandeep Sharma is 5
# Best runs scored by CV Varun against HV Patel is 11
# Best runs scored by V Shankar against DJ Bravo is 57
# Best runs scored by P Simran Singh against T Natarajan is 16
# Best runs scored by OF Smith against Mohammed Siraj is 23
# Best runs scored by FA Allen against Ravi Bishnoi is 5
# Best runs scored by TS Mills against B Kumar is 6
# Best runs scored by Aman Hakim Khan against B Kumar is 5
# Best runs scored by YS Chahal against SM Curran is 4
# Best runs scored by KR Sen against Yash Dayal is 0
# Best runs scored by Akash Deep against RA Jadeja is 0
# Best runs scored by K Gowtham against TA Boult is 22
# Best runs scored by Rasikh Salam against K Rabada is 5
# Best runs scored by CJ Jordan against M Prasidh Krishna is 13
# Best runs scored by DJ Willey against CV Varun is 8
# Best runs scored by SE Rutherford against CV Varun is 15
# Best runs scored by Abdul Samad against A Nortje is 29
# Best runs scored by TL Seifert against DR Sams is 9
# Best runs scored by Mustafizur Rahman against TA Boult is 7
# Best runs scored by Navdeep Saini against HV Patel is 8
# Best runs scored by Anmolpreet Singh against JR Hazlewood is 15
# Best runs scored by RA Bawa against SP Narine is 8
# Best runs scored by NM Coulter-Nile against Mohammed Shami is 12
# Best runs scored by EJG Morgan against GJ Maxwell is 45
# Best runs scored by Shakib Al Hasan against DJ Bravo is 44
# Best runs scored by AB de Villiers against JJ Bumrah is 131
# Best runs scored by DT Christian against KA Pollard is 19
# Best runs scored by TK Curran against SP Narine is 27
# Best runs scored by SK Raina against PP Chawla is 175
# Best runs scored by SS Tiwary against A Mishra is 46
# Best runs scored by J Yadav against R Ashwin is 13
# Best runs scored by SPD Smith against SL Malinga is 72
# Best runs scored by CH Morris against DJ Bravo is 40
# Best runs scored by C Sakariya against Arshdeep Singh is 5
# Best runs scored by JJ Roy against JJ Bumrah is 39
# Best runs scored by S Kaul against TG Southee is 7
# Best runs scored by KA Jamieson against Harbhajan Singh is 11
# Best runs scored by AF Milne against SN Thakur is 9
# Best runs scored by CH Gayle against B Kumar is 131
# Best runs scored by KM Jadhav against A Mishra is 46
# Best runs scored by GD Phillips against SM Curran is 13
# Best runs scored by Sandeep Sharma against DW Steyn is 6
# Best runs scored by SM Curran against SP Narine is 34
# Best runs scored by DL Chahar against R Ashwin is 24
# Best runs scored by T Shamsi against Avesh Khan is 1
# Best runs scored by GHS Garton against B Kumar is 1
# Best runs scored by MC Henriques against A Mishra is 48
# Best runs scored by K Yadav against JJ Bumrah is 0
# Best runs scored by PP Chawla against SR Watson is 22
# Best runs scored by Mohammad Nabi against JJ Bumrah is 21
# Best runs scored by Sachin Baby against Mustafizur Rahman is 23
# Best runs scored by DJ Malan against I Sharma is 12
# Best runs scored by Mohammed Shami against Avesh Khan is 12
# Best runs scored by Virat Singh against KA Pollard is 6
# Best runs scored by KL Nagarkoti against AS Rajpoot is 7
# Best runs scored by Harbhajan Singh against DJ Bravo is 46
# Best runs scored by Mujeeb Ur Rahman against Rashid Khan is 9
# Best runs scored by JA Richardson against RA Jadeja is 7
# Best runs scored by CR Woakes against Mustafizur Rahman is 12
# Best runs scored by S Nadeem against SP Narine is 6
# Best runs scored by BA Stokes against RA Jadeja is 44
# Best runs scored by CA Lynn against YS Chahal is 87
# Best runs scored by SP Goswami against R Bhatia is 35
# Best runs scored by Gurkeerat Singh against R Ashwin is 39
# Best runs scored by AT Carey against JC Archer is 11
# Best runs scored by JC Archer against L Ngidi is 26
# Best runs scored by SS Cottrell against T Natarajan is 0
# Best runs scored by T Banton against Navdeep Saini is 13
# Best runs scored by M Vijay against P Kumar is 85
# Best runs scored by SR Watson against SL Malinga is 125
# Best runs scored by P Dubey against RD Chahar is 3
# Best runs scored by JR Philippe against S Nadeem is 15
# Best runs scored by T Natarajan against S Dube is 2
# Best runs scored by I Udana against Mohammed Shami is 8
# Best runs scored by VR Aaron against L Balaji is 15
# Best runs scored by TU Deshpande against JO Holder is 13
# Best runs scored by Imran Tahir against KH Pandya is 7
# Best runs scored by AS Rajpoot against Kuldeep Yadav is 7
# Best runs scored by DW Steyn against KK Cooper is 16
# Best runs scored by NS Naik against BB Sran is 9
# Best runs scored by AJ Tye against MJ McClenaghan is 14
# Best runs scored by JL Pattinson against L Ngidi is 6
# Best runs scored by DS Kulkarni against R Ashwin is 19
# Best runs scored by MJ McClenaghan against PP Chawla is 13
# Best runs scored by C Munro against KK Ahmed is 21
# Best runs scored by KMA Paul against B Kumar is 6
# Best runs scored by A Mishra against MM Patel is 32
# Best runs scored by I Sharma against RA Jadeja is 10
# Best runs scored by MJ Guptill against Imran Tahir is 21
# Best runs scored by Basil Thampi against BCJ Cutting is 11
# Best runs scored by YK Pathan against A Mishra is 94
# Best runs scored by PA Patel against MM Sharma is 93
# Best runs scored by C de Grandhomme against Rashid Khan is 33
# Best runs scored by STR Binny against DJ Bravo is 57
# Best runs scored by IS Sodhi against I Sharma is 2
# Best runs scored by CA Ingram against GC Viljoen is 24
# Best runs scored by H Klaasen against Mohammed Siraj is 23
# Best runs scored by P Negi against JJ Bumrah is 27
# Best runs scored by BB Sran against AD Russell is 2
# Best runs scored by AJ Turner against B Kumar is 2
# Best runs scored by DR Shorey against Mohammed Siraj is 7
# Best runs scored by CR Brathwaite against SN Thakur is 40
# Best runs scored by AD Nath against RA Jadeja is 13
# Best runs scored by GC Viljoen against K Rabada is 2
# Best runs scored by Y Prithvi Raj against B Kumar is 0
# Best runs scored by KC Cariappa against CH Gayle is 10
# Best runs scored by BCJ Cutting against SR Watson is 48
# Best runs scored by RK Bhui against A Mishra is 5
# Best runs scored by JL Denly against I Sharma is 0
# Best runs scored by SD Lad against AS Rajpoot is 14
# Best runs scored by HF Gurney against SC Kuggeleijn is 1
# Best runs scored by Yuvraj Singh against JH Kallis is 70
# Best runs scored by MM Sharma against R Vinay Kumar is 20
# Best runs scored by GH Vihari against R Vinay Kumar is 22
# Best runs scored by S Lamichhane against SM Curran is 0
# Best runs scored by P Ray Barman against S Kaul is 7
# Best runs scored by M Markande against S Kaul is 7
# Best runs scored by JPR Scantlebury-Searles against BB Sran is 6
# Best runs scored by MK Tiwary against PP Chawla is 56
# Best runs scored by AD Hales against Avesh Khan is 28
# Best runs scored by Anureet Singh against Imran Tahir is 8
# Best runs scored by DJM Short against Shivam Mavi is 19
# Best runs scored by P Chopra against SN Thakur is 4
# Best runs scored by JP Duminy against JJ Bumrah is 70
# Best runs scored by NV Ojha against JA Morkel is 68
# Best runs scored by BB McCullum against R Vinay Kumar is 94
# Best runs scored by LE Plunkett against JD Unadkat is 1
# Best runs scored by MG Johnson against CH Morris is 21
# Best runs scored by CJ Anderson against AR Patel is 48
# Best runs scored by G Gambhir against Z Khan is 109
# Best runs scored by B Laughlin against SL Malinga is 2
# Best runs scored by A Dananjaya against Mohammed Shami is 2
# Best runs scored by B Stanlake against BCJ Cutting is 5
# Best runs scored by R Vinay Kumar against JP Faulkner is 22
# Best runs scored by MA Wood against JJ Bumrah is 1
# Best runs scored by LMP Simmons against RA Jadeja is 61
# Best runs scored by KV Sharma against J Botha is 22
# Best runs scored by IR Jaggi against SL Malinga is 12
# Best runs scored by Bipul Sharma against R Sharma is 15
# Best runs scored by SL Malinga against AB Dinda is 14
# Best runs scored by Vishnu Vinod against Z Khan is 8
# Best runs scored by TM Head against UT Yadav is 21
# Best runs scored by MN Samuels against SB Jakati is 17
# Best runs scored by Z Khan against P Kumar is 16
# Best runs scored by SE Marsh against Harbhajan Singh is 84
# Best runs scored by Swapnil Singh against DT Christian is 5
# Best runs scored by DR Smith against Iqbal Abdulla is 82
# Best runs scored by JP Faulkner against MG Johnson is 37
# Best runs scored by Ankit Soni against MJ McClenaghan is 7
# Best runs scored by P Kumar against SK Warne is 27
# Best runs scored by MM Patel against DP Nannes is 22
# Best runs scored by HM Amla against SL Malinga is 51
# Best runs scored by S Aravind against A Singh is 13
# Best runs scored by S Badree against GJ Maxwell is 5
# Best runs scored by A Choudhary against Basil Thampi is 8
# Best runs scored by IK Pathan against RP Singh is 68
# Best runs scored by AR Bawne against NM Coulter-Nile is 6
# Best runs scored by DM Bravo against SN Thakur is 4
# Best runs scored by AP Tare against JP Faulkner is 30
# Best runs scored by AD Mathews against M Muralitharan is 43
# Best runs scored by Ankit Sharma against R Ashwin is 18
# Best runs scored by R Bhatia against R Vinay Kumar is 20
# Best runs scored by A Zampa against A Mishra is 5
# Best runs scored by AB Dinda against CH Gayle is 6
# Best runs scored by Iqbal Abdulla against DJ Bravo is 16
# Best runs scored by ER Dwivedi against SR Watson is 12
# Best runs scored by R Sathish against R Vinay Kumar is 20
# Best runs scored by SB Jakati against DP Nannes is 11
# Best runs scored by F Behardien against CJ Jordan is 7
# Best runs scored by KJ Abbott against AD Russell is 10
# Best runs scored by UT Khawaja against J Yadav is 15
# Best runs scored by GJ Bailey against MM Sharma is 42
# Best runs scored by NLTC Perera against SP Narine is 32
# Best runs scored by M Morkel against MG Johnson is 14
# Best runs scored by PV Tambe against VR Aaron is 4
# Best runs scored by S Kaushik against Sachin Baby is 0
# Best runs scored by UBT Chand against D Wiese is 20
# Best runs scored by A Nehra against STR Binny is 7
# Best runs scored by PSP Handscomb against Harbhajan Singh is 3
# Best runs scored by A Ashish Reddy against AD Mathews is 25
# Best runs scored by Parvez Rasool against B Kumar is 5
# Best runs scored by JA Morkel against SK Warne is 89
# Best runs scored by KP Pietersen against Harbhajan Singh is 45
# Best runs scored by KW Richardson against R Ashwin is 14
# Best runs scored by P Sahu against CR Brathwaite is 11
# Best runs scored by D Wiese against DJ Bravo is 27
# Best runs scored by MEK Hussey against JH Kallis is 62
# Best runs scored by MA Starc against L Balaji is 11
# Best runs scored by Azhar Mahmood against R Vinay Kumar is 28
# Best runs scored by BE Hendricks against A Nehra is 1
# Best runs scored by RS Bopara against P Kumar is 60
# Best runs scored by J Botha against PP Ojha is 29
# Best runs scored by GB Hogg against HV Patel is 7
# Best runs scored by Karanveer Singh against CH Morris is 5
# Best runs scored by RN ten Doeschate against AG Murtaza is 27
# Best runs scored by NJ Maddinson against Z Khan is 5
# Best runs scored by V Sehwag against RP Singh is 88
# Best runs scored by J Theron against P Awana is 5
# Best runs scored by DJ Muthuswami against HV Patel is 1
# Best runs scored by MS Bisla against R Ashwin is 52
# Best runs scored by RR Rossouw against MM Sharma is 12
# Best runs scored by AN Ahmed against A Mithun is 12
# Best runs scored by RG More against AD Russell is 2
# Best runs scored by DJG Sammy against SR Watson is 33
# Best runs scored by CM Gautam against Sandeep Sharma is 21
# Best runs scored by DJ Hussey against A Mishra is 53
# Best runs scored by PP Ojha against UT Yadav is 2
# Best runs scored by BJ Hodge against DJ Bravo is 46
# Best runs scored by Y Venugopal Rao against SB Jakati is 31
# Best runs scored by S Anirudha against S Ladda is 15
# Best runs scored by YV Takawale against M Morkel is 40
# Best runs scored by VH Zol against A Nehra is 9
# Best runs scored by S Rana against L Balaji is 12
# Best runs scored by KK Cooper against S Nadeem is 16
# Best runs scored by VS Malik against Z Khan is 5
# Best runs scored by M de Lange against WD Parnell is 1
# Best runs scored by Shivam Sharma against MA Starc is 4
# Best runs scored by WD Parnell against PP Ojha is 11
# Best runs scored by LRPL Taylor against Harbhajan Singh is 46
# Best runs scored by R Shukla against STR Binny is 7
# Best runs scored by DH Yagnik against SL Malinga is 23
# Best runs scored by M Manhas against PP Chawla is 49
# Best runs scored by LR Shukla against DJ Bravo is 23
# Best runs scored by L Balaji against A Symonds is 9
# Best runs scored by JH Kallis against Z Khan is 92
# Best runs scored by BR Dunk against AB Dinda is 11
# Best runs scored by CA Pujara against DW Steyn is 25
# Best runs scored by R Rampaul against PV Tambe is 10
# Best runs scored by AM Nayar against R Vinay Kumar is 29
# Best runs scored by S Badrinath against M Kartik is 64
# Best runs scored by R Dravid against PP Ojha is 71
# Best runs scored by CL White against RJ Harris is 42
# Best runs scored by BB Samantray against KK Cooper is 28
# Best runs scored by P Dogra against R Sathish is 22
# Best runs scored by LJ Wright against UT Yadav is 27
# Best runs scored by RV Gomez against WD Parnell is 13
# Best runs scored by DPMD Jayawardene against RP Singh is 70
# Best runs scored by B Chipli against Z Khan is 22
# Best runs scored by BJ Rohrer against Azhar Mahmood is 23
# Best runs scored by AC Gilchrist against A Nehra is 100
# Best runs scored by SK Trivedi against S Ladda is 6
# Best runs scored by RE van der Merwe against PP Ojha is 19
# Best runs scored by DB Das against DJ Bravo is 22
# Best runs scored by SMSM Senanayake against R Ashwin is 2
# Best runs scored by SR Tendulkar against I Sharma is 83
# Best runs scored by MC Juneja against MG Johnson is 16
# Best runs scored by AB Agarkar against PJ Sangwan is 17
# Best runs scored by LA Pomersbach against A Nehra is 26
# Best runs scored by A Mithun against RJ Harris is 12
# Best runs scored by M Kartik against PP Ojha is 11
# Best runs scored by Harmeet Singh against JH Kallis is 10
# Best runs scored by P Awana against VR Aaron is 3
# Best runs scored by UA Birla against SP Narine is 4
# Best runs scored by M Rawat against VRV Singh is 14
# Best runs scored by K Upadhyay against R Vinay Kumar is 7
# Best runs scored by MS Gony against SP Narine is 19
# Best runs scored by KC Sangakkara against Harbhajan Singh is 63
# Best runs scored by R McLaren against A Kumble is 17
# Best runs scored by PA Reddy against J Botha is 18
# Best runs scored by BMAJ Mendis against RA Jadeja is 5
# Best runs scored by OA Shah against KA Pollard is 40
# Best runs scored by TL Suman against SK Raina is 31
# Best runs scored by BAW Mendis against RP Singh is 2
# Best runs scored by R Sharma against SL Malinga is 11
# Best runs scored by S Narwal against UT Yadav is 14
# Best runs scored by B Lee against A Singh is 20
# Best runs scored by A Mukund against SR Watson is 9
# Best runs scored by TM Dilshan against SL Malinga is 61
# Best runs scored by KB Arun Karthik against JDP Oram is 10
# Best runs scored by J Syed Mohammad against UT Yadav is 10
# Best runs scored by X Thalaivan Sargunam against JO Holder is 3
# Best runs scored by AG Murtaza against CH Gayle is 4
# Best runs scored by IC Pandey against CH Gayle is 0
# Best runs scored by A Chandila against RP Singh is 2
# Best runs scored by S Sreesanth against Jaskaran Singh is 12
# Best runs scored by SW Tait against A Mishra is 7
# Best runs scored by PC Valthaty against JA Morkel is 34
# Best runs scored by AD Mascarenhas against I Sharma is 8
# Best runs scored by RT Ponting against DT Christian is 12
# Best runs scored by AB McDonald against IK Pathan is 19
# Best runs scored by RJ Harris against SB Jakati is 14
# Best runs scored by DB Ravi Teja against PP Chawla is 30
# Best runs scored by MDKJ Perera against UT Yadav is 9
# Best runs scored by AL Menaria against PP Chawla is 27
# Best runs scored by Sunny Gupta against SB Jakati is 0
# Best runs scored by JEC Franklin against P Kumar is 33
# Best runs scored by RP Singh against JA Morkel is 6
# Best runs scored by M Muralitharan against Pankaj Singh is 5
# Best runs scored by P Parameswaran against A Mithun is 1
# Best runs scored by JD Ryder against KMDN Kulasekara is 42
# Best runs scored by MJ Clarke against V Pratap Singh is 15
# Best runs scored by SC Ganguly against PP Ojha is 65
# Best runs scored by AP Majumdar against KP Appanna is 18
# Best runs scored by CJ Ferguson against DT Christian is 12
# Best runs scored by Harpreet Singh against SR Watson is 6
# Best runs scored by SD Chitnis against AD Russell is 14
# Best runs scored by N Saini against RP Singh is 17
# Best runs scored by HH Gibbs against P Kumar is 46
# Best runs scored by Y Nagar against A Singh is 22
# Best runs scored by MD Mishra against DE Bollinger is 20
# Best runs scored by AC Thomas against A Ashish Reddy is 10
# Best runs scored by DJ Harris against TM Dilshan is 16
# Best runs scored by AA Jhunjhunwala against M Kartik is 19
# Best runs scored by AUK Pathan against JA Morkel is 14
# Best runs scored by RJ Peterson against PP Chawla is 15
# Best runs scored by AA Chavan against M Morkel is 5
# Best runs scored by V Pratap Singh against SL Malinga is 0
# Best runs scored by RE Levi against DE Bollinger is 18
# Best runs scored by DL Vettori against R Bhatia is 12
# Best runs scored by KMDN Kulasekara against P Kumar is 4
# Best runs scored by AC Blizzard against M Morkel is 29
# Best runs scored by DJ Jacobs against Z Khan is 20
# Best runs scored by CJ McKay against IK Pathan is 4
# Best runs scored by M Kaif against AB Dinda is 25
# Best runs scored by BA Bhatt against SP Narine is 6
# Best runs scored by RR Bhatkal against DE Bollinger is 0
# Best runs scored by A Singh against AB Agarkar is 1
# Best runs scored by DAJ Bracewell against R Vinay Kumar is 10
# Best runs scored by DE Bollinger against TM Dilshan is 8
# Best runs scored by Y Gnaneswara Rao against SB Jakati is 11
# Best runs scored by JJ van der Wath against TG Southee is 7
# Best runs scored by CK Langeveldt against RJ Harris is 6
# Best runs scored by S Sohal against AB Dinda is 26
# Best runs scored by FY Fazal against AB Dinda is 19
# Best runs scored by PR Shah against DR Smith is 12
# Best runs scored by JDP Oram against Shoaib Ahmed is 19
# Best runs scored by SK Warne against A Symonds is 16
# Best runs scored by ND Doshi against RP Singh is 0
# Best runs scored by S Sriram against AD Mathews is 8
# Best runs scored by JR Hopes against MS Gony is 26
# Best runs scored by TR Birt against R Vinay Kumar is 26
# Best runs scored by MJ Lumb against JA Morkel is 36
# Best runs scored by A Symonds against SK Warne is 65
# Best runs scored by MV Boucher against A Nehra is 29
# Best runs scored by AS Raut against R Vinay Kumar is 23
# Best runs scored by SJ Srivastava against SL Malinga is 3
# Best runs scored by M Klinger against IK Pathan is 14
# Best runs scored by RR Powar against L Balaji is 25
# Best runs scored by Sunny Singh against SK Raina is 11
# Best runs scored by L Ablish against S Aravind is 0
# Best runs scored by I Malhotra against AM Salvi is 6
# Best runs scored by GC Smith against Z Khan is 53
# Best runs scored by SB Wagh against SL Malinga is 2
# Best runs scored by NL McCullum against SK Trivedi is 8
# Best runs scored by B Akhil against LPC Silva is 19
# Best runs scored by TD Paine against Z Khan is 3
# Best runs scored by JE Taylor against JA Morkel is 2
# Best runs scored by VVS Laxman against A Kumble is 20
# Best runs scored by BJ Haddin against S Aravind is 13
# Best runs scored by Joginder Sharma against DJ Bravo is 7
# Best runs scored by S Randiv against SL Malinga is 2
# Best runs scored by SA Asnodkar against MS Gony is 56
# Best runs scored by AG Paunikar against PP Ojha is 11
# Best runs scored by R Ninan against DW Steyn is 2
# Best runs scored by NJ Rimmington against WD Parnell is 1
# Best runs scored by SB Styris against JA Morkel is 19
# Best runs scored by ML Hayden against JH Kallis is 57
# Best runs scored by CRD Fernando against DE Bollinger is 2
# Best runs scored by Anirudh Singh against LR Shukla is 12
# Best runs scored by B Sumanth against SB Jakati is 8
# Best runs scored by A Kumble against IK Pathan is 6
# Best runs scored by WPUJC Vaas against SJ Srivastava is 12
# Best runs scored by PD Collingwood against CH Gayle is 23
# Best runs scored by AC Voges against IK Pathan is 25
# Best runs scored by Pankaj Singh against A Symonds is 3
# Best runs scored by C Madan against A Nehra is 9
# Best runs scored by KP Appanna against A Mishra is 1
# Best runs scored by ST Jayasuriya against JA Morkel is 51
# Best runs scored by AP Dole against DS Kulkarni is 11
# Best runs scored by MF Maharoof against SK Warne is 27
# Best runs scored by AB Barath against Harbhajan Singh is 13
# Best runs scored by T Thushara against Harmeet Singh is 5
# Best runs scored by RS Sodhi against SL Malinga is 4
# Best runs scored by AA Bilakhia against P Kumar is 12
# Best runs scored by Jaskaran Singh against I Sharma is 3
# Best runs scored by K Goel against MM Patel is 21
# Best runs scored by KAJ Roach against Harbhajan Singh is 5
# Best runs scored by S Ladda against KA Pollard is 0
# Best runs scored by DP Nannes against ST Jayasuriya is 2
# Best runs scored by JM Kemp against PP Ojha is 14
# Best runs scored by DR Martyn against JH Kallis is 7
# Best runs scored by RS Gavaskar against R Ashwin is 1
# Best runs scored by SE Bond against JM Kemp is 1
# Best runs scored by A Uniyal against DP Nannes is 3
# Best runs scored by S Tyagi against A Symonds is 2
# Best runs scored by YA Abdulla against PJ Sangwan is 0
# Best runs scored by Mohammad Ashraful against AM Salvi is 2
# Best runs scored by SM Katich against MS Gony is 27
# Best runs scored by WA Mota against L Balaji is 11
# Best runs scored by RJ Quiney against DJ Bravo is 16
# Best runs scored by NK Patel against S Sreesanth is 18
# Best runs scored by T Henderson against R Vinay Kumar is 8
# Best runs scored by Yashpal Singh against PJ Sangwan is 9
# Best runs scored by SS Shaikh against SK Warne is 5
# Best runs scored by Mashrafe Mortaza against A Symonds is 2
# Best runs scored by C Nanda against MM Patel is 0
# Best runs scored by Shoaib Ahmed against SK Raina is 1
# Best runs scored by AN Ghosh against R Vinay Kumar is 6
# Best runs scored by LA Carseldine against IK Pathan is 14
# Best runs scored by MN van Wyk against R Bhatia is 26
# Best runs scored by SM Harwood against DR Smith is 3
# Best runs scored by L Ronchi against IK Pathan is 10
# Best runs scored by RR Raje against RJ Harris is 7
# Best runs scored by W Jaffer against P Amarnath is 17
# Best runs scored by D du Preez against AS Raut is 4
# Best runs scored by R Bishnoi against VS Malik is 12
# Best runs scored by TM Srivastava against VY Mahesh is 5
# Best runs scored by GR Napier against CH Gayle is 10
# Best runs scored by FH Edwards against P Kumar is 3
# Best runs scored by SB Bangar against A Kumble is 14
# Best runs scored by A Flintoff against DW Steyn is 14
# Best runs scored by T Kohli against GD McGrath is 6
# Best runs scored by A Chopra against RP Singh is 9
# Best runs scored by Kamran Khan against JD Ryder is 3
# Best runs scored by S Vidyut against VY Mahesh is 22
# Best runs scored by CK Kapugedera against SR Watson is 5
# Best runs scored by Kamran Akmal against S Sreesanth is 27
# Best runs scored by Sohail Tanvir against AB Agarkar is 11
# Best runs scored by Mohammad Asif against MM Patel is 2
# Best runs scored by VY Mahesh against B Lee is 4
# Best runs scored by GD McGrath against MM Patel is 4
# Best runs scored by AS Yadav against R Bhatia is 12
# Best runs scored by Shahid Afridi against Joginder Sharma is 20
# Best runs scored by SP Fleming against VY Mahesh is 18
# Best runs scored by SM Pollock against Mohammad Asif is 24
# Best runs scored by Salman Butt against M Muralitharan is 26
# Best runs scored by Umar Gul against JR Hopes is 12
# Best runs scored by Misbah-ul-Haq against R Bhatia is 27
# Best runs scored by LPC Silva against VRV Singh is 16
# Best runs scored by M Ntini against Sohail Tanvir is 11
# Best runs scored by VS Yeligati against VRV Singh is 2
# Best runs scored by Mohammad Hafeez against S Sreesanth is 7
# Best runs scored by DJ Thornely against PJ Sangwan is 13
# Best runs scored by H Das against DJ Bravo is 1
# Best runs scored by DNT Zoysa against CRD Fernando is 9
# Best runs scored by J Arunkumar against Umar Gul is 12
# Best runs scored by DT Patil against SK Warne is 6
# Best runs scored by Abdur Razzak against Sohail Tanvir is 0
# Best runs scored by Shoaib Malik against DS Kulkarni is 9
# Best runs scored by Shoaib Akhtar against DJ Bravo is 1
# Best runs scored by PM Sarvesh Kumar against A Mishra is 1
# Best runs scored by DP Vijaykumar against A Mishra is 1
# Best runs scored by Younis Khan against S Sreesanth is 2
# Best runs scored by D Salunkhe against DL Vettori is 12
# Best runs scored by T Taibu against P Kumar is 11
# Best runs scored by RR Sarwan against Z Khan is 9
# Best runs scored by VRV Singh against DS Kulkarni is 4
# Best runs scored by U Kaul against L Balaji is 0
# Best runs scored by S Chanderpaul against A Nehra is 10
# Best runs scored by D Kalyankrishna against S Sreesanth is 1
# Best runs scored by MA Khote against M Muralitharan is 6
# Best runs scored by SB Joshi against I Sharma is 2
# Best runs scored by DS Lehmann against PP Chawla is 5
# Best runs scored by AA Noffke against SC Ganguly is 7

# %%
# Ratio of Batters
# Number of unique batters and bowlers
num_unique_batters = len(df['Batter'].unique())
num_unique_bowlers = len(df['Bowler'].unique())

# Calculate the ratio
ratio_batter_to_bowler = num_unique_batters / num_unique_bowlers

# Print the ratio
print("Ratio of number of batters to bowlers:", ratio_batter_to_bowler)
# Out:
# Ratio of number of batters to bowlers: 1.2817796610169492

# %%
# Analyzing Dismissal Pattern
dismissal_counts = df['dismissed'].value_counts()
plt.figure(figsize=(8, 6))
dismissal_counts.plot(kind='bar', color='skyblue')
plt.title('Dismissal Patterns')
plt.xlabel('Dismissal Type')
plt.ylabel('Count')
plt.show()

# %%
# Analyzing match played distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['match_played'], bins=20, color='lightgreen', kde=True)
plt.title('Distribution of Matches Played')
plt.xlabel('Matches Played')
plt.ylabel('Frequency')
plt.show()

# %%
#Visualizing runs scored vs Balls faced
plt.figure(figsize=(8, 6))
plt.scatter(df['ball_faced'], df['runs_scored'], color='orange')
plt.title('Runs Scored vs Balls Faced')
plt.xlabel('Balls Faced')
plt.ylabel('Runs Scored')
plt.show()

# %%
#Analyzing Batsmen Impact Distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['batsman_impact'], bins=20, color='lightblue', kde=True)
plt.title('Distribution of Batsman Impact')
plt.xlabel('Batsman Impact')
plt.ylabel('Frequency')
plt.show()
